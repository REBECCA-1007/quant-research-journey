# %%
# Test imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("✅ All libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# ✅ All libraries imported successfully!
# Pandas version: 2.2.3
# NumPy version: 2.1.3

# %%
# Test pandas
data = {
    'coin': ['BTC', 'ETH', 'BNB'],
    'price': [45000, 2500, 300]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   coin  price
# 0  BTC  45000
# 1  ETH   2500
# 2  BNB    300

# %%
# Test numpy
arr = np.array([1, 2, 3, 4, 5])
print(f"Array: {arr}")
print(f"Mean: {arr.mean()}")
print(f"Std: {arr.std()}")
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Std: 1.4142135623730951

# %%
# Test matplotlib
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y)
plt.title("Test Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # Setup Complete! 🎉
#
# Date: 12/3/2026
#
# This is my first notebook in my quant research journey.
#
# ## What I tested:
# - ✅ Pandas
# - ✅ NumPy
# - ✅ Matplotlib
# - ✅ Jupyter in VS Code
#
# ## Next steps:
# - Start Week 1 - Day 1
# - Learn Python fundamentals
# ```
#
# - Chạy cell (Shift + Enter)
#
# ---
#
# ## 🎉 BƯỚC 8: FIRST COMMIT! (10 phút)
#
# ### **8.1 Commit locally:**
#
# **Mở GitHub Desktop:**
# - Sẽ thấy file `test-setup.ipynb` ở phần Changes
# - Ở ô **Summary**, gõ: `Initial setup complete - first notebook`
# - Ở ô **Description**, gõ:
# ```
# - Setup Anaconda, VS Code, GitHub
# - Tested all libraries (pandas, numpy, matplotlib)
# - Created first Jupyter notebook
# - Ready to start Day 1!
